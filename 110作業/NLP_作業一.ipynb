# %%
# !pip install jieba

# %%
import jieba
list = jieba.cut("我要成為國際金融家")   #斷句
print("/".join(list))
# Out:
# 我要/成為/國際/金融家

# %%
file=open('文章.txt','r')
document1=file.read()
document1
# Out:
# '2020年一場全球大疫，劇烈改變人類原本的生活軌道，也為所有人重新創造了面對自我、家庭、事業與社會交互作用的空間與機會。中信金融管理學院校長施光訓重新閱讀了法國知名隨筆作家洛羅的《How to Live More with Less：理想的簡單生活》，更加體悟到擁有愈多、得到的愈少，簡單才能帶來意義與美好。\n超越自我 追求格調\n作者生在法國，在日本旅居30年，大部分時間都在周遊世界各國，思考宗教、哲學、報導文化團體的觀點，描寫生活觀點與文化反思。這本書在2005年出版後，帶動了風靡全球的新生活觀念，也讓Less is More的空間與生活觀念更加深植人心。\n\n施光訓說，常在媒體上看到「窮到只剩下錢」這句高度反差的話，凸顯出台灣在急速前進的環境壓力中，有一大群人面臨「愈努力、卻失落，愈富足、卻空虛」的窘境。推薦這本清新的小品，希望所有人能在高壓與無奈的疫情環境下，調整呼吸與腳步，認識更好的自己。\n\n20世紀30年代美國大蕭條時期，金錢比不上格調重要，因為差不多所有家庭都一貧如洗，展現不同家庭高下之別的不再是金錢財富，而是談吐、教養、文化、道德觀、與對「好東西」的品味。人們每天都在使用自己所擁有最漂亮的物品，會在餐桌上擺一束花。\n\n施光訓表示，生活中總是可以做得更完美些，尤其細節實在是太重要了，「盡善盡美的細節使我們平和安靜，透過細節，我們關注更重要的事物，追求格調和細節的過程，也會幫助我們不斷超越」。\n\n這是一本內省自己身心、生活空間、工作方式、人際關係的書。施光訓最近和幾個朋友透過電話聊到疫情居家辦公的心得：在病毒面前真的人人平等，身分地位與金錢，都已經派不上用場。大家都必須面對真實的自己，愛惜自己，保護自己。\n\n生活軌道上，要學習教導自己的小孩，用心享用自己做的午餐，將大部分的時間和家人相處。雖然大家在事業上都面臨了大波折，或許經濟上多少都有所損失，但卻發現在相對簡單的生活中，調整了自己關注的視野。不再喧囂的人際互動，利用線上會議反而讓思考更銳利，溝通更有效率；離開人群，不再對比物質，「發現金錢是我們的奴僕，不是我們的主人」。\n\n施光訓說，有一樣東西所有人都想竭力長久保持──就是健康。攝取少而精的食物，遵循預防醫學的建議，積極保持理性和擔負責任，就可以常保健康。對於擁有的財物，不管是家電、衣服、汽車等，都要貫徹這種道理，減省節約、
# ...

# %%
jieba.load_userdict('splin1.txt')
seg_list = jieba.cut(document1, cut_all=False)
print("|".join(seg_list))
# Out:
# 2020|年|一場|全球大疫|，|劇烈|改變|人類|原本|的|生活軌道|，|也|為|所有人|重新|創造|了|面|對|自我|、|家庭|、|事業|與|社會|交互作用|的|空間|與|機會|。|中信金融管理學院|校長|施光訓|重新|閱讀|了|法國|知名|隨筆|作家|洛羅|的|《|How| |to| |Live| |More| |with| |Less|：|理想|的|簡單|生活|》|，|更加|體悟|到|擁有|愈多|、|得到|的|愈少|，|簡單|才能|帶來|意義|與|美好|。|
# |超越自我| |追求|格調|
# |作者|生在|法國|，|在|日本|旅居|30|年|，|大部分|時間|都|在|周遊|世界|各國|，|思考|宗教|、|哲學|、|報導|文化|團體|的|觀點|，|描寫|生活|觀點|與|文化|反思|。|這本書|在|2005|年|出版|後|，|帶動了|風靡全球|的|新|生活觀念|，|也|讓|Less| |is| |More|的|空間|與|生活觀念|更加|深植|人心|。|
# |
# |施光訓|說|，|常在|媒體|上|看到|「|窮到|只|剩下|錢|」|這句|高度|反差|的|話|，|凸顯出|台灣|在|急速前進|的|環境|壓力|中|，|有|一大群人|面臨|「|愈|努力|、|卻|失落|，|愈|富足|、|卻|空虛|」|的|窘境|。|推薦|這本|清新|的|小品|，|希望|所有人|能|在|高壓|與|無奈|的|疫情|環境|下|，|調整|呼吸|與|腳步|，|認識|更好|的|自己|。|
# |
# |20世紀|30年代|美國大蕭條|時期|，|金錢|比不上|格調|重要|，|因為|差不多|所有|家庭|都|一貧|如洗|，|展現|不同|家庭|高下之別|的|不再是|金錢|財富|，|而是|談吐|、|教養|、|文化|、|道德|觀|、|與|對|「|好|東西|」|的|品味|。|人們|每天|都|在|使用|自己|所擁|有|最|漂亮|的|物品|，|會在|餐桌上|擺|一束花|。|
# |
# |施光訓|表示|，|生活中|總是|可以|做|得|更|完美|些|，|尤其|細節|實在|是|太|重要|了|，|「|盡善|盡|美的|細節|使|我們|平和|安靜|，|透過|細節|，|我們|關注|更|重要|的|事物|，|追求|格調|和|細節|的|過程|，|也|會|幫助|我們|不斷|超越|」|。|
# |
# ...
